# %%
name = input ("Enter your name: ")
print("hello, "+ name )
# Out:
# Enter your name:   vedaanshi verma
# hello,  vedaanshi verma

# %%
name = input("Enter your name: ")
print("Hello, " + name)
print(type(name))
# Out:
# Enter your name:  vedaanshi verma
# Hello, vedaanshi verma
# <class 'str'>

# %%
num = (input("Enter a number: "))
print(num)
print(type(num))
# Out:
# Enter a number:  20
# 20
# <class 'str'>

# %%
num = float((input("Enter a number: ")))
print(num)
print(type(num))
num=num+3
print(num)
# Out:
# Enter a number:  12345
# 12345.0
# <class 'float'>
# 12348.0

# %%
num = bool((input("Enter a number: ")))
print(num)
print(type(num))
num=num-2
print(num)
# Out:
# Enter a number:  12
# True
# <class 'bool'>
# -1

# %%
num = bool((input("Enter a number: ")))
print(num)
print(type(num))
# Out:
# Enter a number:  123456
# True
# <class 'bool'>

# %%
letter = "hey name is {1} and I am from {0}"
country  = "India"
name = "vedaanshi verma"

print(f"Hey my name is {name} and I am from {country}")

# %%
message = "hey this is python programming"
name = "vedaanshi verma"
print(f"{message}, my name is {name}")
